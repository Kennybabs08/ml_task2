# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv('energydata_complete.csv')

# %%
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
simple_linear_reg_df = df[['T2', 'T6']].sample(15, random_state =2)

# %%
simple_linear_reg_df
# Out:
#               T2         T6
# 1117   17.426667  -4.238889
# 16275  22.760000  14.690000
# 13272  21.230000   8.926667
# 3160   21.100000   7.690000
# 19210  21.856667  10.800000
# 8260   17.356667   5.000000
# 12299  19.000000   5.300000
# 13505  22.700000  17.133333
# 12913  19.593333   7.545000
# 17788  21.890000   9.190000
# 17894  21.500000   5.160000
# 7665   19.142857   0.937500
# 10165  18.000000   0.200000
# 18809  22.400000  16.833333
# 8737   17.066667   1.900000

# %%
from sklearn.metric import r2_score
r2_score = r2_score(T6,T2)
round(r2_score,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11028\816581054.py in <module>
# ----> 1 from sklearn.metric import r2_score
#       2 r2_score = r2_score(T6,T2)
#       3 round(r2_score,3)
#
# ModuleNotFoundError: No module named 'sklearn.metric'

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
features_df = normalised_df.drop(columns = ["date", "lights"])
target_var = normalised_df["Appliances"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11028\725840973.py in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler = MinMaxScaler()
# ----> 3 normalised_df = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
#       4 features_df = normalised_df.drop(columns = ["date", "lights"])
#       5 target_var = normalised_df["Appliances"]
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
features_df = normalised_df.drop(columns = ['date', 'light'])
heating_target = normalised_df['Appliances']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11028\2222461787.py in <module>
#       3
#       4 scaler = MinMaxScaler()
# ----> 5 normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
#       6 features_df = normalised_df.drop(columns = ['date', 'light'])
#       7 heating_target = normalised_df['Appliances']
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     414         # Reset internal state before fitting
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11028\2037243009.py in <module>
# ----> 1 df.shape()
#       2
#       3
#       4
#       5
#
# TypeError: 'tuple' object is not callable
